# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/home/ltgwgeorge/Downloads/ds/train.csv')
df.head()
# Out:
#    id  CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0   0  15616088.0   Flemming        656.0   Germany  Female  54.0     4.0
# 1   1  15616709.0     Ch'eng        715.0    France  Female  33.0     1.0
# 2   2  15763029.0  Nkemdirim        602.0   Germany    Male  52.0     9.0
# 3   3  15769216.0   Chidozie        567.0     Spain    Male  29.0     4.0
# 4   4  15773949.0       Tsao        538.0    France  Female  32.0     9.0
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0   91286.51            1.0        1.0             0.0        149550.95
# 1   95377.13            1.0        1.0             0.0        147955.81
# 2  146034.74            1.0        0.0             0.0        120158.72
# 3       0.00            2.0        0.0             0.0         95686.40
# 4  121355.99            1.0        1.0             0.0         93783.00
#
#    Exited
# 0     1.0
# 1     0.0
# 2     1.0
# 3     0.0
# 4     0.0

# %%
df.describe()
# Out:
#                  id    CustomerId   CreditScore           Age        Tenure  \
# count  15000.000000  1.500000e+04  15000.000000  15000.000000  15000.000000
# mean    7499.500000  1.569174e+07    657.665533     37.743067      5.036800
# std     4330.271354  7.123790e+04     72.807663      8.259330      2.794966
# min        0.000000  1.556571e+07    431.000000     18.000000      0.000000
# 25%     3749.750000  1.563355e+07    602.000000     32.000000      3.000000
# 50%     7499.500000  1.568924e+07    661.000000     37.000000      5.000000
# 75%    11249.250000  1.575688e+07    708.000000     42.000000      7.000000
# max    14999.000000  1.581566e+07    850.000000     72.000000     10.000000
#
#              Balance  NumOfProducts     HasCrCard  IsActiveMember  \
# count   15000.000000   15000.000000  15000.000000    15000.000000
# mean    42660.619213       1.587667      0.779133        0.492800
# std     59883.366301       0.527067      0.414845        0.499965
# ...

# %%
columns = df.columns
for column in columns:
    df[column].isnull

# %%
plt.scatter(df['CreditScore'], df['Age'], color='b', marker='o')

# Adding labels and title
plt.xlabel('Credit Score')
plt.ylabel('Age')
plt.title('Scatter Plot of Credit Score vs Age')

# Show plot
plt.show()
